# %% [markdown]
# # Correctness Evaluation
#
# This page shows the process of testing the correctness of the RAG system using Langsmith, which is a framwework focused on testing, monitoring and deployment of LLM apps, and provides tools for QA Correctness via QA Evaluators . These [evaluators](https://docs.smith.langchain.com/evaluation/faq/evaluator-implementations#correctness-qa-evaluation) can be used to measure the accuracy of the system's answers against a set of reference answers.
#
# To test the correctness of the RAG system, a train-validation-test approach were defined, and the *test* part of the split will be used to perform these tests.
#
# First of all , we extract the question and answer that will be used for reference in a list of tuples:

# %%
import dotenv
import pandas as pd

dotenv.load_dotenv()

df_test = pd.read_csv("../data/split_files/test_counsel_chat.csv")
df_test = df_test[["questionTitle", "answerText"]]

list_examples = list(df_test.itertuples(index=False, name=None))

# %% [markdown]
# After that, the Langsmith client is instantiated to interact with the Langsmith platform

# %%
from langsmith import Client

client = Client()

# %% [markdown]
# The dataset has defined a name to be identified across tests, and in this part the question/answer pairs used for reference are stored in the dataset on Langsmith platform

# %%
dataset_name = f"Mental Health Retrieval QA Questions"
dataset = client.create_dataset(dataset_name=dataset_name)

for q, a in list_examples:
    client.create_example(
        inputs={"question": q}, outputs={"answer": a}, dataset_id=dataset.id
    )

# %% [markdown]
# In this case, we will be using the chain-of-thought Q&A correctness evaluator `cot-qa`. This evaluator measures the accuracy of the system's answers based on how well they follow the logical flow of the conversation. And we also use the `qa` evaluator, which only grade a response as "correct" or "incorrect" based on the reference answer.

# %%
from langchain.smith import RunEvalConfig

eval_config = RunEvalConfig(
    # We will use the chain-of-thought Q&A correctness evaluator
    evaluators=["cot_qa","qa"],
)

# %% [markdown]
# Next we configure the prompts, retrievers and LLM models used, in this case `gpt-3.5-turbo-16k`, for the chain to be executed in Langsmith platform

# %%
from langchain_community.vectorstores.chroma import Chroma
from operator import itemgetter
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import ChatPromptTemplate

FAQ_CHROMA_PATH = "../data/vector"

faqs_retriever = Chroma(
    embedding_function=OpenAIEmbeddings(), persist_directory=FAQ_CHROMA_PATH
).as_retriever(k=10)

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a helpful documentation Q&A assistant, trained to answer"
            " questions from Mental health."
            "Answer only based on the following context:",
        ),
        ("system", "{context}"),
        ("human", "{question}"),
    ]
)

model = ChatOpenAI(model="gpt-3.5-turbo-16k", temperature=0)

response_generator = prompt | model | StrOutputParser()

faq_rag_chain = (
        {
            "context": faqs_retriever,
            "question": itemgetter("question"),
        }
        | response_generator
)

# %% [markdown]
# Once we have created the dataset and structured the chain, we can run the evaluations on the dataset using the run_on_dataset method of the Langsmith client. We need to provide the name of the dataset, the LLM or chain factory function, and the evaluation configuration.

# %%
client.run_on_dataset(
    dataset_name=dataset_name, llm_or_chain_factory=faq_rag_chain, evaluation=eval_config
)
# Out:
# View the evaluation results for project 'best-discovery-95' at:
# https://smith.langchain.com/o/adc22f44-a515-576d-9880-914687081682/datasets/97aea489-e162-4ed9-a5a0-06c51f5ebff0/compare?selectedSessions=fded5dcf-0eaf-45a9-8e4c-b5f34e2e0173
#
# View all tests for Dataset Mental Health Retrieval QA Questions at:
# https://smith.langchain.com/o/adc22f44-a515-576d-9880-914687081682/datasets/97aea489-e162-4ed9-a5a0-06c51f5ebff0
# [------------------------------------------------->] 117/117
# {'project_name': 'best-discovery-95',
#  'results': {'c7f84acb-dddd-47a2-a59b-a783a565182d': {'input': {'question': 'Is it normal to cry during therapy?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context states that it is normal to express various emotions, including crying, during therapy sessions. The student's answer also states that it is normal to cry during therapy and provides additional information on why this might occur and how it can be beneficial. Therefore, the student's answer is factually accurate and does not conflict with the context.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('ef35e11a-4a84-438a-be95-a7ab334a133e'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('1ac28a92-6a06-41eb-bf9f-b493b208fa3e'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 5.916905,
#    'run_id': '34c42952-4624-4814-bcef-417ce6146ff2',
#    'output': 'Yes, it is normal to cry during therapy. Therapy often involves exploring deep emotions and discussing unsatisfying or unfulfilling relationships and situations. When painful emotions arise, crying can be a natural response. Crying can help you realize emotional hurt and unfairness, and it can clear the way for new ways of handling interactions. Therapists are aware of this and typically have tissues available for their clients. Crying during therapy can be a healthy release and can lead to increased awareness and the establishment of new and happier patterns of relating.',
#    'reference': {'answer': "Please do not worry about crying. People cry, laugh, rage, rant, and talk during counseling sessions. Part of the therapy process is to look at your feelings, and to feel what you are actually feeling (instead of what you think you should feel). So if you need to cry, that's ok. If you feel embarrassed because you cried, or if you feel anxious that you might cry, well those feelings are ok as well. Your counselor can help you manage your feelings so that you can attain your goals, and your counseling session is the perfect place for that."}},
#   '6d25da20-8277-4fcf-a123-5c8c3aa24206': {'input': {'question': 'Is it normal to cry during therapy?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context suggests that crying during therapy is a normal response to discussing painful emotions and experiences. The student's answer reflects this understanding, stating that crying can be a natural response to these discussions and can serve as a healthy release of emotions. The student also correctly notes that therapists are trained to create a safe and supportive environment for clients to express their emotions, which is implied in the context when the therapist mentions having tissues ready for clients. Therefore, the student's answer is factually accurate.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('fd927eaf-eb1d-4b25-be72-30524acb7328'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('f2195bb1-8248-4c73-8c35-a32050a15ef6'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 4.237168,
#    'run_id': '308a800d-d166-45b4-a22f-53f7a3fef4bb',
#    'output': 'Yes, it is normal to cry during therapy. Therapy often involves exploring deep emotions and discussing challenging experiences. Crying can be a natural response to these discussions and can serve as a healthy release of emotions. Therapists are trained to create a safe and supportive environment, and they are prepared for clients to express their emotions, including crying. So, there is no need to worry or feel embarrassed if you cry during therapy.',
#    'reference': {'answer': 'Please feel free to cry during therapy if you suddenly feel painful emotions arising when you describe some of your unsatisfying and unfulfilling relationships and situations.Crying when realizing the emotional hurt and unfairness between you and someone, clears you for new ways of handling interactions.As a therapist, I always have a box of tissues on the table next to the couch where people who utilize my therapy, sit.I hope you will soon discover that once your tears unlock your awareness of harmful relationships in your life, you will quickly see the freedom to establish new and happier patterns of relating.Have a good therapy!'}},
#   '954e7454-5894-4c8f-8640-bdc7aa63af34': {'input': {'question': 'Is it normal to cry during therapy?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context states that crying is a normal human response to pain and is an important part of the healing process. The student's answer also states that crying is a natural response to the discussions in therapy and can serve as a healthy release of emotions. Both the context and the student's answer agree that it is normal to cry during therapy. Therefore, the student's answer is correct.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('9d7ce140-f2f7-466f-ad8f-8b9a2bfed2f1'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('1875a004-990d-4e29-a196-47d41d6f3622'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 4.228568,
#    'run_id': '6fb2c89c-6052-4ee7-a40a-f2edb34fc8a9',
#    'output': 'Yes, it is normal to cry during therapy. Therapy often involves exploring deep emotions and discussing challenging experiences. Crying can be a natural response to these discussions and can serve as a healthy release of emotions. Therapists are trained to create a safe and supportive environment, and they are prepared for clients to express their emotions, including crying. So, there is no need to worry or feel embarrassed if you cry during therapy.',
#    'reference': {'answer': "Many people cry during their therapy sessions. Actually most people cry in their therapist's office. I tell my clients that it's safe to cry in my office and crying isn't a sign of weakness. It's a normal human response to pain. People actually do more harm to themselves by trying not to cry than by crying. Crying is very cleansing and an important part of the healing process for many people."}},
#   '8ee18a4d-4a99-47cb-abe3-3e81dcb252c2': {'input': {'question': 'Is it normal to cry during therapy?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context mentions that crying is a natural response during therapy and therapists are comfortable with this. The student's answer also mentions that crying is a natural response and therapists are prepared for this. Therefore, the student's answer is factually accurate.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('76c7098a-358d-4a10-9762-6ee6ce002038'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('434a5fe6-5e91-481b-a6ca-7d80912643a0'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 4.226567,
#    'run_id': '92848b93-bd36-4e0b-91d3-3f33fb0b6550',
#    'output': 'Yes, it is normal to cry during therapy. Therapy often involves exploring deep emotions and discussing challenging experiences. Crying can be a natural response to these discussions and can serve as a healthy release of emotions. Therapists are trained to create a safe and supportive environment, and they are prepared for clients to express their emotions, including crying. So, there is no need to worry or feel embarrassed if you cry during therapy.',
#    'reference': {'answer': 'Lots of people do cry in session, but your therapist won\'t be uneasy with this. \xa0Crying is a natural response and it also releases toxins, so some might say it\'s necessary! \xa0Remember that you can be in charge of what you talk about in your session and if there\'s something that feels too uncomfortable, just say, "I\'m not ready to talk about that." \xa0Your counselor wants \xa0you to feel at ease and will probably not push you right away to a very uncomfortable place. \xa0As you get to know your therapist, you will feel more relaxed and even not worry so much about how you appear to them. \xa0It\'s normal to be anxious going into a new situation especially when you might not feel in control of uncomfortable emotions. \xa0Don\'t give up, go and put your best effort in!\xa0Hope that helps,\xa0Allison'}},
#   'b7ddd8c0-cc9d-4d52-b099-2f1a3140d1f3': {'input': {'question': 'Is it normal to cry during therapy?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context states that crying is a normal part of therapy and is nothing to worry about. The student's answer also states that crying is normal and can be a healthy release of emotions. The student also correctly states that therapists are prepared for clients to express their emotions, including crying, which is also mentioned in the context. Therefore, the student's answer is factually accurate.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('2b7f3e1d-19e7-48b2-ae8f-665558dfdee7'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('4bfb8666-18d7-4991-a59d-a377ff61823b'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 4.425728,
#    'run_id': '2f0fef19-2f14-4dc3-8fd8-5d8094d0a212',
#    'output': 'Yes, it is normal to cry during therapy. Therapy often involves exploring deep emotions and discussing challenging experiences. Crying can be a natural response to these discussions and can serve as a healthy release of emotions. Therapists are trained to create a safe and supportive environment, and they are prepared for clients to express their emotions, including crying. So, there is no need to worry or feel embarrassed if you cry during therapy.',
#    'reference': {'answer': "Hi there ! \xa0As someone who has practiced as a clinical psychologist for 25 years , I would say that crying is NOTHING TO WORRY ABOUT AT ALL ! Almost every single person I have worked with has cried at one point or another. \xa0Starting therapy takes a lot of courage; when you work with a therapist ,once you feel safe , \xa0you talk about a lot of very private and potentially emotional things that you may have never discussed with anyone before. \xa0I have seen \xa0people cry with sadness , cry with relief at releasing painful things they have held onto for a long time, cry because they feel so relieved that they finally feel heard. \xa0 I myself have sometimes cried with clients because some things they talk about are so profoundly moving. \xa0\xa0I can assure you that most , if not all , therapists expect clients to cry \xa0and there is nothing to be embarrassed about. \xa0 Crying can be very cathartic and can allow us to release a lot of painful feelings we have been stuffing down. \xa0 Crying is \xa0often a sign that you are really working things through and getting in touch with feelings that you need to get in touch with in order to heal .So , to summarize , don't worry at all about crying! It will probably feel uncomfortable \xa0at first , but I promise you , you will not be judged for crying in therapy. \xa0 And it will be less embarrassing once it happens a time or two and you are assured that your therapist will be there for you and won't judge you !Good luck !!"}},
#   '155664a6-330f-42b8-b13c-16c805cd5703': {'input': {'question': 'Is it normal to cry during therapy?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context states that crying is a natural response when discussing difficult issues in therapy, and therapists are equipped to handle such emotional responses. The student's answer reflects this understanding, stating that crying is a normal part of therapy and therapists are trained to handle it. The student also adds that therapy is a safe and supportive environment, which is implied in the context. Therefore, the student's answer is factually accurate.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('0b1e6b7e-3b5f-4d3d-b2d7-11e4b970ebfd'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('03d5e230-32e6-46b3-94c9-243cec91abf0'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 3.697409,
#    'run_id': '3cff9a5b-5006-4f4c-9822-f4cbef1fb660',
#    'output': 'Yes, it is normal to cry during therapy. Therapy often involves exploring deep emotions and discussing challenging experiences. Crying can be a natural response to these discussions and can serve as a healthy release of emotions. Therapists are trained to create a safe and supportive environment, and they are prepared for clients to express their emotions, including crying. So, there is no need to worry or feel embarrassed if you cry during therapy.',
#    'reference': {'answer': 'When talking about difficult issues, it is very normal to cry. Crying is a natural way for us to cope with the sadness that we experience in life. When confronting some of these things in a counseling session, tears just seem to come naturally. Every Counselor should be well equipped to handle that level of emotion, and you would be far from the first to cry when talking with a Counselor.'}},
#   '98008652-269e-4686-b369-c9c2c97045a3': {'input': {'question': 'Is it normal to cry during therapy?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context states that it is normal to cry during therapy and the student's answer also states that it is normal to cry during therapy. The student also provides additional information about why it is normal and how therapists are prepared for this, which does not conflict with the context. Therefore, the student's answer is correct.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('0a9e1800-c46f-4c6b-bccd-d09c07227afa'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('f0f11ca2-ce60-4511-8560-4c8b4872de16'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 3.782691,
#    'run_id': '3a38c0e3-0ab1-4dc3-994a-2f5219575dc0',
#    'output': 'Yes, it is normal to cry during therapy. Therapy often involves exploring deep emotions and discussing challenging experiences. Crying can be a natural response to these discussions and can serve as a healthy release of emotions. Therapists are trained to create a safe and supportive environment, and they are prepared for clients to express their emotions, including crying. So, there is no need to worry or feel embarrassed if you cry during therapy.',
#    'reference': {'answer': "It is is absolutely normal to cry in therapy. I can understand wanting to keep everything together and put your best foot forward with everyone you come into contact with, but it can be such a powerful experience to cry with somebody that can hear you and accept you. It's so brave of you to go and share yourself with your counselor! I hope you will keep being brave as you begin healing."}},
#   '7e40b32a-5987-472e-a144-744e0af2a2f4': {'input': {'question': 'Is it normal to cry during therapy?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context states that crying is a normal part of therapy and can be encouraged as a way to express emotions. The student's answer also states that crying is normal during therapy and can be a healthy release of emotions. The student also adds that therapists are aware of this and typically have tissues available for their clients, which is additional information but does not conflict with the context. Therefore, the student's answer is correct.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('8ada995b-75e9-452c-b9cf-e12d4158de75'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('0e14b56f-1653-4ecb-b302-b6d05c51bef6'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 4.544958,
#    'run_id': 'bd1a276a-bae2-4475-85b1-f326e12b6a48',
#    'output': 'Yes, it is normal to cry during therapy. Therapy often involves exploring deep emotions and discussing unsatisfying or unfulfilling relationships and situations. When painful emotions arise, crying can be a natural response. Crying can help you realize emotional hurt and unfairness, and it can clear the way for new ways of handling interactions. Therapists are aware of this and typically have tissues available for their clients. Crying during therapy can be a healthy release and can lead to increased awareness and the establishment of new and happier patterns of relating.',
#    'reference': {'answer': "Yes, if crying is how you are expressing an emotion, then not only would it be normal, but hopefully encouraged, because it's an important part of therapy to have a safe space to express your emotions. We might encourage you to put words to the tears as well, to help you expand on your experience and begin to make more sense of it.As a therapist, our job is help you open up and feel comfortable enough doing so. I sincerely hope no therapist would ever shame you for whatever experience you are having in the room."}},
#   '943efcbd-7ad7-4ce2-998d-8e767fbfe017': {'input': {'question': 'Is it normal to cry during therapy?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context states that it is okay to cry during therapy and that the therapist will honor this as part of the process. The student's answer expands on this by explaining why it is normal to cry during therapy, stating that it can be a natural response to discussing deep emotions and unsatisfying or unfulfilling situations. The student also mentions that therapists are aware of this and typically have tissues available for their clients, which is not in conflict with the context. Therefore, the student's answer is correct.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('9d22cc9f-8206-42e6-a313-11ec46e35dc6'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('db896ab5-63fb-4433-bb99-fb01a217745a'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 4.41096,
#    'run_id': '5fbf6524-5043-4a16-8a8d-a0dad5e73b31',
#    'output': 'Yes, it is normal to cry during therapy. Therapy often involves exploring deep emotions and discussing unsatisfying or unfulfilling relationships and situations. When painful emotions arise, crying can be a natural response. Crying can help you realize emotional hurt and unfairness, and it can clear the way for new ways of handling interactions. Therapists are aware of this and typically have tissues available for their clients. Crying during therapy can be a healthy release and can lead to increased awareness and the establishment of new and happier patterns of relating.',
#    'reference': {'answer': 'It is not uncommon to be a bit nervous meeting your therapist (or another person) for the first time. Your therapist understands that calling and getting an appointment was a big step for you and will do their best to put you at ease. Providing a safe environment for our clients includes not judging them and being comfortable with the information and emotions that they share with us. It is ok to cry and to trust that the therapist will honor this as part of your process.'}},
#   'e008c5d2-d91c-4e21-b1b4-f2bceb289d48': {'input': {'question': 'Is it normal to cry during therapy?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context explains that crying is a natural process when discussing upsetting things, especially in therapy. The student's answer reflects this by stating that crying can be a natural response to discussing deep emotions and challenging experiences in therapy. The student also correctly mentions that therapists are trained to create a safe and supportive environment for their clients, which is implied in the context. Therefore, the student's answer is factually accurate.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('8a9e7a3b-9ae3-470f-8258-dca3e74e021f'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('af0cae1a-4125-407d-ac47-e720338030fc'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 3.976958,
#    'run_id': '6e7d1b6a-8838-4fbe-aee5-e7c9bc777545',
#    'output': 'Yes, it is normal to cry during therapy. Therapy often involves exploring deep emotions and discussing challenging experiences. Crying can be a natural response to these discussions and can serve as a healthy release of emotions. Therapists are trained to create a safe and supportive environment, and they are prepared for clients to express their emotions, including crying. So, there is no need to worry or feel embarrassed if you cry during therapy.',
#    'reference': {'answer': "Crying is a natural process when you talk about upsetting things especially in therapy when you are opening up and being so vulnerable. I suggest that you consider how you would feel/respond to someone that was confiding to you and they began to cry. If you felt concerned, supportive and empathetic then you know exactly how us therapists feel when our clients are emotional in sessions. I suggest that you think of times where you have cried and how you felt at that time in public and what would have helped to make you feel less uncomfortable during your tears.\xa0I think of crying like any other natural reaction of our body such as sneezing, laughing, coughing. You can't help but do those things and most people won't really judge negatively if you do it in public. Similarly, crying is our body's reaction when we are emotional whether it is tears of joy, from a hilarious joke or from being upset.\xa0If you are very uncomfortable about crying but willing to start therapy perhaps you can ask the therapist if you can turn your chair around if you begin crying. This way you are not facing them and can self soothe without worrying about how you physically look at that time.I wish you luck and you should be proud of yourself for starting therapy and I wish you a wonderful journey on this important path that you are embarking on."}},
#   'ccba14ea-4982-415d-9175-993d1ff97c7c': {'input': {'question': 'Is it normal to cry during therapy?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer is in line with the context provided. The context mentions that it is normal for people to cry during therapy, especially when they feel safe and comfortable with their counselor. The student's answer also states that it is normal to cry during therapy, and further explains that crying can be a natural response to discussing deep emotions and unsatisfying situations. The student's answer does not contradict the context in any way, and provides additional information that is accurate and relevant to the question. Therefore, the student's answer is correct.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('b143fda6-e22a-4eea-9cda-b8b2b865f2a8'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('b32f0427-9a5c-4a61-9c41-26bd6b040386'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 4.651406,
#    'run_id': 'ab05f888-1f8b-40ff-9a48-8f8791d2a9e4',
#    'output': 'Yes, it is normal to cry during therapy. Therapy often involves exploring deep emotions and discussing unsatisfying or unfulfilling relationships and situations. When painful emotions arise, crying can be a natural response. Crying can help you realize emotional hurt and unfairness, and it can clear the way for new ways of handling interactions. Therapists are aware of this and typically have tissues available for their clients. Crying during therapy can be a healthy release and can lead to increased awareness and the establishment of new and happier patterns of relating.',
#    'reference': {'answer': "People do cry in therapy sometimes, but it's not at all necessary to cry in order for most kinds of therapy to be helpful. When you start counseling you don't yet know your counselor very well, so it's normal to keep your feelings in check until you feel comfortable and a bit more relaxed with your counselor and with the situation. Sometimes, though, there are emotions that have been waiting and waiting to finally find someone who will listen with a kind ear. If you feel safe right away in the situation with your counselor, you might just cry in spite of your fears about it. Your therapist is used to people expressing how they feel and will keep strict confidentiality, so even though it's embarrassing, finally experiencing someone truly listening with empathy and kindness may just be worth it. It's okay too to let your counselor know right at the beginning that you're kind of freaked out about getting too emotional in front of another person."}},
#   '3c0a5125-b825-46de-bf1a-78ba73cbb91c': {'input': {'question': 'Is it normal to cry during therapy?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context states that crying in therapy is normal and therapists are used to it. The student's answer expands on this by explaining why it is normal and how it can be beneficial. The student's answer does not contradict the context in any way.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('e8cba9be-f032-4a77-840b-41c55432ca1b'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('69b3747c-0271-4474-b799-d85ba61d8dbe'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 4.764585,
#    'run_id': '7e0db9c3-9d39-4324-a44f-e3a64fda1a5e',
#    'output': 'Yes, it is normal to cry during therapy. Therapy often involves exploring deep emotions and discussing unsatisfying or unfulfilling relationships and situations. When painful emotions arise, crying can be a natural response. Crying can help you realize emotional hurt and unfairness, and it can clear the way for new ways of handling interactions. Therapists are aware of this and typically have tissues available for their clients. Crying during therapy can be a healthy release and can lead to increased awareness and the establishment of new and happier patterns of relating.',
#    'reference': {'answer': "Oh, crying in therapy is very normal! I have a stack of kleenex boxes in my office. Cry away, therapist are very used to it:) First time being in therapy is scary, but you'll soon know if you are a good match."}},
#   'd40a745f-43d3-4955-a931-0d9f44245f66': {'input': {'question': 'Is it normal to go into therapy feeling nervous?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context states that it is normal to feel nervous when going into therapy, and the student's answer agrees with this, explaining that therapy is an unusual way to have a conversation and it's normal to feel nervous. The student also provides additional information about why one might feel nervous and how this nervousness might dissipate over time, which does not conflict with the context. \nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('fe3a1d21-72d3-405c-b83a-4996d44833d2'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('393892b1-8faa-4e97-8b91-048698c33a60'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 5.231645,
#    'run_id': '51179e4f-48ef-457a-ba43-4f6426d25da9',
#    'output': "Yes, feeling nervous for the first few or several sessions of therapy is completely normal. Therapy is an unusual way to have a conversation with someone, and for some people, the fear is that the therapist knows more about you than you do yourself. It's important to remember that your therapist has likely worked with many other people who have faced similar problems, but they couldn't possibly know your particular details and areas of upset. As you start to trust your own right to tell your story and feel that your therapist is listening attentively and cares about what you say, your nervousness will start to disappear on its own. Good luck in getting the most from your therapy sessions!",
#    'reference': {'answer': "It is totally normal - you have a lot riding on this and you're invested! Think about why you feel so shaky - is it something about the therapist or their style? If so, it would be a good idea to talk with them about it so you feel more at ease. In any case bringing up your feelings about therapy in\xa0therapy is totally appropriate and even necessary. Good luck!"}},
#   '1871ec48-f59d-405f-97ef-fbc91eb1e19a': {'input': {'question': 'Is it normal to go into therapy feeling nervous?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context suggests that it's not unusual to feel nervous when starting therapy and that it's important to address these feelings with the therapist. The student's answer also acknowledges that it's normal to feel nervous, especially in the beginning, and that this nervousness will likely decrease as trust is built with the therapist. The student's answer does not contradict the context in any way.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('c1081c01-ece5-4abc-b0f6-d863cc53977d'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('fff589bf-f35b-4ba5-87a2-0ab846532274'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 5.556334,
#    'run_id': '2850dd35-394e-4f0d-9952-bcf3fe6cf959',
#    'output': "Yes, feeling nervous for the first few or several sessions of therapy is completely normal. Therapy is an unusual way to have a conversation with someone, and for some people, the fear is that the therapist knows more about you than you do yourself. It's important to remember that your therapist has likely worked with many other people who have faced similar problems, but they couldn't possibly know your particular details and areas of upset. As you start to trust your own right to tell your story and feel that your therapist is listening attentively and cares about what you say, your nervousness will start to disappear on its own. Good luck in getting the most from your therapy sessions!",
#    'reference': {'answer': "I would be more concerned with how is this being addressed in therapy. Therapy can be a rewarding process, however often times we do not pay much attention to the messages being sent to our bodies. I believe in somatic therapy which deals with our mind & body connection. I would think it may not be a question of normal or abnormal however if it is impacting you then you must pay attention to that. It would be helpful to explore the feelings you're having \xa0with your therapist. It may be something that needs addressing to help alleviate those feelings or have a better understanding of why they are showing up when it is time for therapy."}},
#   '4df8cb64-5969-4444-99af-78b0ab86bd75': {'input': {'question': 'Is it normal to go into therapy feeling nervous?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context states that being nervous can be a typical emotion one might feel when going to therapy. The student's answer also acknowledges that feeling nervous for the first few or several sessions of therapy is completely normal. The student further explains why one might feel nervous and provides reassurance that the nervousness will start to disappear as one gets comfortable with the therapy sessions. Therefore, the student's answer is factually accurate.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('0b0bb287-e77b-4fbe-928c-4558f02067b4'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('405ba03b-b163-40ab-9d84-8fc101b57ddc'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 4.948483,
#    'run_id': 'b32f33db-6df0-4fa0-8b43-49070fa77112',
#    'output': "Yes, feeling nervous for the first few or several sessions of therapy is completely normal. Therapy is an unusual way to have a conversation with someone, and for some people, the fear is that the therapist knows more about you than you do yourself. It's important to remember that your therapist has likely worked with many other people who have faced similar problems, but they cannot possibly know your particular details and areas of upset. As you start to trust your own right to tell your story and feel that your therapist is listening attentively and cares about what you say, your nervousness will start to disappear on its own. Good luck in getting the most from your therapy sessions!",
#    'reference': {'answer': "Everyone has different experiences going to therapy. Being nervous can be a typical emotion one might feel. Emotions are our body's way of telling us important information about ourselves. I would suggest talking openly in your sessions about this. That way you can process your thoughts and feelings with the guidance of your counselor. There are probably underlining emotions (fears or insecurities) that are being stirred up during your therapy sessions. Your counselor might suggest individual counseling depending on what you learn about your anxiety. In individual therapy you would have time to deal with your own stressors. As you address your issues, then you will have tools and skills that will be useful in addressing the couple relationship."}},
#   '2dc5a803-7873-4f76-a089-6e26e8e72cfb': {'input': {'question': 'Is it normal to go into therapy feeling nervous?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer is in line with the context provided. The context suggests that it's important to pay attention to your emotional experiences when attending therapy, including feelings of anxiety or nervousness. The student's answer acknowledges that it's normal to feel nervous when starting therapy and provides a detailed explanation of why this might be the case. The student also encourages the reader to trust in their own experiences and in the therapist's ability to listen and care, which aligns with the context's suggestion to explore feelings and thoughts without judgement. Therefore, the student's answer is factually accurate.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('c1b4ac28-6f53-4ab0-a69b-9b0ef9f75625'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('f8b9600b-1efa-4e0a-80f6-c3c9ef5cedf0'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 5.140382,
#    'run_id': '17a695b2-dd59-4667-a738-e5a34ef459f2',
#    'output': "Yes, feeling nervous for the first few or several sessions of therapy is completely normal. Therapy is an unusual way to have a conversation with someone, and for some people, the fear is that the therapist knows more about you than you do yourself. It's important to remember that your therapist has likely worked with many other people who have faced similar problems, but they cannot possibly know your particular details and areas of upset. As you start to trust your own right to tell your story and feel that your therapist is listening attentively and cares about what you say, your nervousness will start to disappear on its own. Good luck in getting the most from your therapy sessions!",
#    'reference': {'answer': '"Normal" can be an insidious word to use because it can undermine your sense of worth. \xa0It implies there\'s one particular way you should be behaving and can leave you feeling crappy and "abnormal" if you\'re not behaving according to that prescribed standard. \xa0Instead, what I\'d recommend is to pay attention to your emotional experiences when you\'re attending therapy. \xa0Explore your feelings and thoughts without judgement and try to reflect and understand what\'s going on that\'s causing you anxiety. \xa0Once you figure out the underlying meaning of the anxiety, you can figure out a way to handle it and action steps to take to diminish it.'}},
#   '4dbfac6b-cc09-40bc-9c94-5ba3155378a3': {'input': {'question': 'Is it normal to go into therapy feeling nervous?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context confirms that it is normal to feel nervous when going into therapy, especially if it's a new experience or if there are deep personal issues to be discussed. The student's answer also mentions that this nervousness is normal and will start to disappear as trust is built with the therapist. Therefore, the student's answer is factually correct.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('96294d78-0be5-4000-938b-9aa615807da7'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=None, value=None, comment="Error evaluating run 551f5e09-9038-4a4e-a577-a6d935ed01b6: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-yGejNetcUkMLCsQiZcwh2KJQ on tokens per min (TPM): Limit 10000, Used 9630, Requested 690. Please try again in 1.92s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}", correction=None, evaluator_info={}, source_run_id=None, target_run_id=None)],
#    'execution_time': 4.897941,
#    'run_id': '551f5e09-9038-4a4e-a577-a6d935ed01b6',
#    'output': "Yes, feeling nervous for the first few or several sessions of therapy is completely normal. Therapy is an unusual way to have a conversation with someone, and for some people, the fear is that the therapist knows more about you than you do yourself. It's important to remember that your therapist has likely worked with many other people who have faced similar problems, but they couldn't possibly know your particular details and areas of upset. As you start to trust your own right to tell your story and feel that your therapist is listening attentively and cares about what you say, your nervousness will start to disappear on its own. Good luck in getting the most from your therapy sessions!",
#    'reference': {'answer': "Hello there.\xa0 You ask about being nervous and shaky walking in to your therapy session and want to know if its normal? ...\xa0 I realize there a few ways to look at this.\xa0 I presume you weren't\xa0anticipating feeling this way; and probably hoped to feel the opposite..\xa0 Well, my initial response is yes, sure, it can be within reason to feel this way.\xa0 Have you been in therapy before? Is this somewhat new? That could be part of the reason. But either way; new or not, I think when are entering into a meeting that holds potential evaluation of deep things about you and your heart and soul, it can cause anyone to tremble. The soul can be anticipating some things could be shaken up here, and it can feel scary to look at these things and then change.\xa0 Looking deep at our life can feel daunting and scary; so your response just might be regards to potential growth trying to happen.\xa0\xa0 OR, is there something about the therapist you don't feel confident about?\xa0 This too might be in play as a reason for your feelings...\xa0 Maybe you lack confidence in that therapist ?\xa0 Have you let your therapist know how you feel?\xa0 That would be good to explore...I would like to encourage you to look at these ideas.\xa0 Hope it helps.\xa0\xa0 Let me knowKindly,keithkeithcounseling.com"}},
#   '011d0e88-d903-4a32-a8a6-041e9f38a089': {'input': {'question': 'Is it normal to go into therapy feeling nervous?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=None, value=None, comment="Error evaluating run 0fce8110-d874-4368-9ede-246234c6089d: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-yGejNetcUkMLCsQiZcwh2KJQ on tokens per min (TPM): Limit 10000, Used 9914, Requested 560. Please try again in 2.844s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}", correction=None, evaluator_info={}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('731685b3-d6d0-4a26-bc39-df4704ce1216'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 6.969618,
#    'run_id': '0fce8110-d874-4368-9ede-246234c6089d',
#    'output': "Yes, feeling nervous for the first few or several sessions of therapy is completely normal. Therapy is an unusual way to have a conversation with someone, and for some people, the fear is that the therapist knows more about you than you do yourself. It's important to remember that your therapist has likely worked with many other people who have faced similar problems, but they cannot possibly know your particular details and areas of upset. As you start to trust your own right to tell your story and feel that your therapist is listening attentively and cares about what you say, your nervousness will start to disappear on its own. Good luck in getting the most from your therapy sessions!",
#    'reference': {'answer': "It's normal to feel a little anxiety--after all it's an important encounter for you. \xa0My suggestion is to discuss this with your therapist, let him/her know how you're feeling, especially if you feel as though your level of anxiety is impacting the quality and benefit of your sessions. \xa0You might try some relaxation techniques prior to starting the session, deep breathing, progressive relaxation, core muscle dis-engagement--If you're not familiar with these techniques ask your therapist or write back."}},
#   'ff408f30-093b-44d4-ad42-5bf454a8cc84': {'input': {'question': 'Is it normal to go into therapy feeling nervous?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer aligns with the context provided. The context states that it is normal to feel nervous when starting therapy, and the student's answer agrees with this, explaining that therapy is an unusual situation and it's normal to feel nervous. The student also provides additional information about why someone might feel nervous and how this nervousness might decrease over time, which does not conflict with the context. Therefore, the student's answer is correct.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('2aae96e9-7b98-405e-a38c-a01655194a60'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('f4964883-2b1e-435c-9b54-17851c3134cb'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 5.013964,
#    'run_id': '7f842abc-8263-4c7b-be0f-43770fb43d8f',
#    'output': "Yes, feeling nervous for the first few or several sessions of therapy is completely normal. Therapy is an unusual way to have a conversation with someone, and for some people, the fear is that the therapist knows more about you than you do yourself. It's important to remember that your therapist has likely worked with many other people who have faced similar problems, but they cannot possibly know your particular details and areas of upset. As you start to trust your own right to tell your story and feel that your therapist is listening attentively and cares about what you say, your nervousness will start to disappear on its own. Good luck in getting the most from your therapy sessions!",
#    'reference': {'answer': 'It is absolutely a typical response.\xa0 Many of my clients are nervous the first couple of times we meet.\xa0 This is\xa0essentially a stranger\xa0with whom\xa0you are sharing\xa0your\xa0feelings.'}},
#   'ebc30af5-6083-48a7-9edf-36af21a3fb63': {'input': {'question': 'Is it normal to go into therapy feeling nervous?'},
# ...
#    'reference': {'answer': "People often have very different values and opinions when they are drinking excessively and when they stop drinking so much.Did the two of you share drinking as an activity? \xa0If yes, then did you stop drinking too?Often when partners meet each other as drinking buddies when one gets sober, the relationship ends. \xa0Once the terms of any relationship changes, one possibility is that it dissolves.The best way to go is to start the conversation of what you genuinely want. \xa0This is the only way she'll really know your thoughts.Ask her to give serious consideration and discussion over at least a few weeks or months, to moving away from you. \xa0This is a fair request since you are in a relationship.If she's changed so much by giving up drinking, which is possible, that she no longer wants to be in relationship to you, then you are better off being without a drinking gf, even if the truth she delivers is a hurtful one."}},
#   '6a3b75dc-ea43-420e-9ed3-f525d4a1af9c': {'input': {'question': 'How can I help my girlfriend?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=None, value=None, comment="Error evaluating run 738b4ea3-bb4f-4f27-a2a6-67a78f9f93f4: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-yGejNetcUkMLCsQiZcwh2KJQ on tokens per min (TPM): Limit 10000, Used 9478, Requested 1223. Please try again in 4.206s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}", correction=None, evaluator_info={}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('fc56f8d6-48ce-4aaf-a849-e35f4f96c4b3'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 15.243649,
#    'run_id': '738b4ea3-bb4f-4f27-a2a6-67a78f9f93f4',
#    'output': "It seems like your girlfriend recently quit drinking and has become depressed. She has also expressed a desire to move. Different therapists have provided different perspectives on how you can help her:\n\n1. Sherry Katz, LCSW (Couples and Family Therapist) suggests starting a conversation with your girlfriend about what you genuinely want. Ask her to give serious consideration and discussion over a few weeks or months to moving away from you. This is a fair request since you are in a relationship. If she no longer wants to be in a relationship with you due to the changes she has experienced after quitting drinking, it may be better for you to be without a drinking girlfriend, even if the truth she delivers is hurtful.\n\n2. Earl Lewis (Relationship Expert) advises speaking with your girlfriend about what has her feeling down. Explore if there have been significant events in her life or in your relationship that may be affecting both of you. Since she just stopped drinking, she may be struggling to find alternative and healthier behaviors. You can explore this together. Additionally, encourage her to speak to a therapist to discuss her feelings about quitting alcohol. Let her know that you are there for her as a support system, despite her pushing you away.\n\n3. Denisha Forch (Marriage and Family Therapist) suggests talking to your girlfriend about her depression and letting her know that you are there for her as a support system. Encourage her to engage in activities she enjoys and to get connected with a community of people, as this can help with feelings of depression. It may also be beneficial for her to speak with a therapist or counselor to address her depression, considering the major change she has made in her life by deciding to stop drinking. While you can express your desire for her to stay, ultimately, you will need to respect her boundaries and the decision she chooses to make.\n\n4. Kristi King-Morgan, LMSW (Social Worker, Psychotherapist) emphasizes that it is important to consider what your girlfriend wants and what may be best for her, rather than solely focusing on what you want. Quitting an addiction often involves making significant changes, such as removing triggers and moving to new locations. It may be helpful for your girlfriend to have some time alone to focus on herself and make decisions for her own well-being. Support her, but avoid pressuring her to stay. Let her have the freedom to do what she needs to do, even if it means moving. Encourage her to seek therapy or counseling to address her depression and provide her with the support she needs during this time.\n\nRemember, each situation is unique, and it's important to consider your girlfriend's individual needs and desires. Communication, support, and respecting her boundaries are key elements in helping her through this challenging time.",
#    'reference': {'answer': 'I would say talk to her about her depression. The best thing you can do is let her know that you are there for her as a support system. I would encourage her to talk more if it helps and encourage her to get move involved in doing activities she likes to do. Also, getting connected in a community of people is important to help with feeling depressed. Encourage her to speak with a therapist or counselor to address her depression as she has made a major change in her life by deciding to stop drinking. She may believe moving is the best to help with this. You can share with her that you want her to stay and express to her how you feel. Ultimately, you will have to respect her boundaries and the decision she chooses to make. She may want to move and this may be what she feels is best for her life. If she does choose to move that will be her decision. It sounds like she is trying to do what is going to make her happy. Maybe staying in the city she is currently in is causing her more feelings of sadness.'}},
#   '1aa18e50-95bb-44c3-89e0-5593f6301aba': {'input': {'question': 'How can I help my girlfriend?'},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer is comprehensive and aligns with the context provided. The student has correctly identified the key points from the context, such as the girlfriend's recent quitting of drinking, her depression, and her desire to move. The student has also correctly identified the need for communication, support, and respecting her boundaries. The student has also correctly identified the potential need for therapy or counseling, and the importance of not pressuring her to stay. The student has also correctly identified the potential need for the girlfriend to have some time alone to focus on herself. Therefore, the student's answer is correct.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('a10724ba-186f-4e57-8c59-c175032e81e5'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('57e03485-7cb2-449b-8ea9-b75149ffe11c'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 20.823376,
#    'run_id': '1122c1af-4ed1-4052-bf54-1cad3dd11672',
#    'output': "It seems like your girlfriend has recently quit drinking and is now feeling depressed. She has also expressed a desire to move. Different therapists have provided different suggestions on how you can help her:\n\n1. Sherry Katz, LCSW (Couples and Family Therapist) suggests starting a conversation with your girlfriend about what you genuinely want. Ask her to give serious consideration and discussion over a few weeks or months to moving away from you. This is a fair request since you are in a relationship. If she no longer wants to be in a relationship with you due to the changes she has experienced after quitting drinking, it may be better for you to be without a drinking girlfriend, even if the truth she delivers is hurtful.\n\n2. Earl Lewis (Relationship Expert) advises speaking with your girlfriend about what has her feeling down. Explore if there have been significant events in her life or in your relationship that may be affecting both of you. Since she has recently stopped drinking, she may be struggling to find alternative and healthier behaviors. You can explore these together. Additionally, encourage her to speak to a therapist to discuss her feelings about quitting alcohol. Let her know that you are there for her as a support system, despite her pushing you away.\n\n3. Denisha Forch (Marriage and Family Therapist) suggests talking to your girlfriend about her depression and letting her know that you are there for her as a support system. Encourage her to engage in activities she enjoys and to get connected with a community of people, as this can help with feelings of depression. It may also be beneficial for her to speak with a therapist or counselor to address her depression, considering the major change she has made in her life by deciding to stop drinking. While you can express your desire for her to stay, ultimately, you will need to respect her boundaries and the decision she makes.\n\n4. Kristi King-Morgan, LMSW (Social Worker, Psychotherapist) emphasizes that it is important to consider what your girlfriend wants and what may be best for her, rather than solely focusing on what you want. Quitting an addiction often involves making significant changes, such as removing triggers and moving to new locations. It may be helpful for your girlfriend to have some time alone to focus on herself and make decisions for her own well-being. Support her, but avoid pressuring her to stay. Let her have the freedom to do what she needs to do, even if it means moving. Encourage her to speak with a therapist or counselor to address her depression and provide her with the support she needs during this time.\n\nRemember, each situation is unique, and it's important to consider your girlfriend's individual needs and desires. Communication, support, and respecting her boundaries are key in helping her through this challenging time.",
#    'reference': {'answer': 'You\'re probably not going to like my answer.Your question says a lot about what YOU want rather than what she wants or what may be best for her. Sometimes, what\'s best for a person is the hardest thing to do, and may be completely opposite of what YOU want.Addictions don\'t happen in a vacuum. If you\'ve had any experience with addicts at all, then I\'m sure you\'ve heard the term "enabler". A lot of the times, when people think they\'re "helping", they\'re actually enabling the addict to continue their self-destructive behavior. Tough love and clear boundaries are needed in a lot of situations, but especially with addictions. Family and friends are often the biggest contributing factor to someone choosing to use/drink, continuing to do so, or relapsing back into it.You said she recently quit. You said she is depressed. She wants to move. When a person receives counseling for addictions, they are encouraged to make changes like this. They need to break the habit, and this means removing people from their lives at times. It means moving to new locations. Anything that may trigger a relapse needs to be identified and removed. Not only that, but the addict needs to do a lot of personal reflection to figure out WHY they use/drink in the first place, and not only break the physical addiction to it, but deal with whatever is the root cause that led them to use in the first place. She may need some time alone to figure out who she is as a person, time to make some decisions for herself and do what she needs to do to be healthy.Don\'t pressure her to stay. Let her have the freedom to do what she needs to do. If she stays, the decision needs to be hers and hers alone. It doesn\'t need to be made under pressure. That will only lead to resentment. Support her, but don\'t try to change her or make her do anything, especially for selfish reasons. Let her go. It sounds like she needs some time to focus on herself right now. It wouldn\'t be a bad idea for you to do the same.'}},
#   'c55d380f-8583-4be4-ab5c-399f97c76111': {'input': {'question': "Is wishing I wasn't born a sign of something deeper?"},
#    'feedback': [EvaluationResult(key='COT Contextual Accuracy', score=1, value='CORRECT', comment="The student's answer is a direct restatement of the context provided. The student has not added any conflicting information or left out any key details from the context. The student's answer accurately reflects the information given in the context.\nGRADE: CORRECT", correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('8af47431-5cf2-4ad0-ae4a-1c50842e088f'))}, source_run_id=None, target_run_id=None),
#     EvaluationResult(key='correctness', score=1, value='CORRECT', comment='CORRECT', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('c7315381-7680-4a00-bc53-158a2f634a5e'))}, source_run_id=None, target_run_id=None)],
#    'execution_time': 4.550392,
#    'run_id': 'b33cb455-ee12-419e-b02f-c05fb428b5f2',
#    'output': "Sounds like a sign of great unhappiness, or sadness, or insecurity. The real way you'll find out what this feeling is about is to ask yourself your own question. Inside you are the only one who will feel when you discover the true answer to your question. Everyone feels some amount of discontent in their lives once in a while. It's normal to not feel entirely happy all the time. Try to accept your unhappiness as motivation to learn more about who you are, what you like, whom you like. Study yourself because this way you increase the chance to find a road which feels right and happy.",
#    'reference': {'answer': "Sounds like a sign of great unhappiness, or sadness, or insecurity.The real way you'll find out what this feeling is about is to ask yourself your own question. \xa0Inside you are the only one who will feel when you discover the true answer to your question.Everyone feels some amount of discontent in their lives once in a while. Its normal to not feel entirely happy all the time.Try to accept your unhappiness as motivation to learn more about who you are, what you like, whom you like.Study yourself bc this way you increase the chance to find a road which feels right and happy."}}},
#  'aggregate_metrics': None}

# %% [markdown]
# Finally, the results can be seen on the Langsmith website, with explanation and details about the results.

# %% [markdown]
# ![title](correctness_tests_results.png "Correctness tests in LangSmith")

# %% [markdown]
# Additionally, you can see the contextual feedback about the results on any example that was tested

# %% [markdown]
# ![title](correctness_tests_details.png "Correctness tests explanation in LangSmith")

# %% [markdown]
# ## Next steps
#
# The next steps would be to do benchmarking between different [LLMs](https://python.langchain.com/docs/integrations/llms/) (LangChain supports plenty of them), different chain dispositions, and additional fine-tuning, As it is shown here, where we can edit some parameters, prompts, or messages in the interaction with the LLM model to check how it performs after the changes

# %% [markdown]
# ![title](correctness_test_playground_1.png "Correctness tests Playground")

# %% [markdown]
# ![title](correctness_test_playground_2.png "Correctness tests Playground ChatOpenAI")
